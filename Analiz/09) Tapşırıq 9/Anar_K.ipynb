# %% [markdown]
# # Tapşırıq 9.
#
# ## Ötən ilki Novruz endirim kompaniyamıza baxaq görək müştərilər daha çox hansı kateqoriyadan olan məhsulları alıblar, bu il də onlara üstünlük verək. Mmm, yaxşı olardı ki, hansı məhsullarla birlikdə, bu məhsullar hansı filiallarımızdan nə qədər alınıb, bunu da bilək ki, həmin filiallara o məhsulları daha çox stoklayaq. Müəllim, bu ikisini zəhmət olmasa, birlikdə bizə asan başa düşülən qrafik şəklində hazırlayardız.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("esas_mehsullar.csv")
df = data.copy()
df.head()
# Out:
#    column_a  satish_kodu  mehsul_kodu  \
# 0         0       577571         3334
# 1         1       577571         4674
# 2         2       577571         8388
# 3         3       577571         6017
# 4         4       577571         8297
#
#                                       mehsul_ad  mehsul_kateqoriya  \
# 0  GONDOL SIMPLE LABABO VE BUZLUK HALISI G61*50  Məişət məhsulları
# 1                              TAXTA BICAQ 3232          Qab-qacaq
# 2                        VITA 1LT ANANAS SIRESI     Meyvə Şirələri
# 3          GILAN BAGDAN 1LT SARI GAVALI KOMPOTU          Kompotlar
# 4      OSRAM SUPERSTAR LAMPA 64544A ECO 57W E27  Məişət məhsulları
#
#    mehsul_qiymet        satish_tarixi  endirim_kompaniya  bonus_kart  \
# 0           3.68  2019-07-19T12:29:00  Sərin Yay günləri        True
# 1           2.25  2019-07-19T12:29:00  Sərin Yay günləri        True
# 2           2.50  2019-07-19T12:29:00  Sərin Yay günləri        True
# 3           1.45  2019-07-19T12:29:00  Sərin Yay günləri        True
# 4           2.92  2019-07-19T12:29:00  Sərin Yay günləri        True
#
#   magaza_ad  magaza_lat  magaza_long               magaza_location
# 0    Zabrat   40.485561    49.946741  POINT(49.9467409 40.4855613)
# 1    Zabrat   40.485561    49.946741  POINT(49.9467409 40.4855613)
# 2    Zabrat   40.485561    49.946741  POINT(49.9467409 40.4855613)
# 3    Zabrat   40.485561    49.946741  POINT(49.9467409 40.4855613)
# 4    Zabrat   40.485561    49.946741  POINT(49.9467409 40.4855613)

# %%
df["endirim_kompaniya"].unique()
# Out:
# array(['Sərin Yay günləri', nan, 'Yeni il fürsətləri',
#        'Payız endirimləri', 'S?rf?li Yaz', 'Bərəkətli Novruz'],
#       dtype=object)

# %%
# novruz endirim kompaniyasına aid olan sətirlər

novruz = df[df["endirim_kompaniya"] == "Bərəkətli Novruz"]

# %%
novruz
# Out:
#         column_a  satish_kodu  mehsul_kodu  \
# 126          126       868654         9175
# 127          127       868654         9917
# 128          128       868654         2791
# 129          129       868654         9313
# 143          143       970385         7123
# ...          ...          ...          ...
# 438711    438711       367857         9528
# 438822    438822       458448         6645
# 438823    438823       458448         4171
# 438824    438824       458448         5279
# 438825    438825       458448         7977
#
#                                             mehsul_ad  \
# 126                              JIQULI 2LT PIVE PL/Q
# 127                  BINGO SOFT 2LT LOVELY YUMSALDICI
# 128                    BEBETO 35GR JELEBON DRINK COLA
# 129                       BERRAK 1600GR QARISIQ TURSU
# 143     CAVENDISH&HARVEY 50GR MANPASI LEMON DROPS D/Q
# ...                                               ...
# 438711      SORBON 200GR QUTU SOKOLAD MINI CONE SOHAN
# 438822               SIGARET SOBRANIE KS SLIMS BLACKS
# 438823                     TACH BULASIK SUNGERI 10-LU
# 438824                   KONFET SUVOROV PLOMBIRINI KG
# 438825                   DAMLA 350ML BULAQ SUYU SPORT
#
#                mehsul_kateqoriya  mehsul_qiymet        satish_tarixi  \
# 126                      Pivələr           5.35  2019-03-14T22:13:00
# 127      Yuyucu, təmizləyicilər            4.45  2019-03-14T22:13:00
# 128                    Şirniyyat           0.50  2019-03-14T22:13:00
# 129                     Turşular           5.45  2019-03-14T22:13:00
# 143                    Şirniyyat           2.10  2019-03-05T17:47:00
# ...                          ...            ...                  ...
# 438711                 Şirniyyat           5.30  2019-03-30T07:57:00
# 438822          Tütün məhsulları           3.60  2019-03-01T23:13:00
# 438823   Yuyucu, təmizləyicilər            1.90  2019-03-01T23:13:00
# 438824                 Şirniyyat           8.50  2019-03-01T23:13:00
# 438825                     Sular           0.35  2019-03-01T23:13:00
#
#        endirim_kompaniya  bonus_kart          magaza_ad  magaza_lat  \
# 126     Bərəkətli Novruz       False  C. Məmmədquluzadə   40.395400
# 127     Bərəkətli Novruz       False  C. Məmmədquluzadə   40.395400
# 128     Bərəkətli Novruz       False  C. Məmmədquluzadə   40.395400
# 129     Bərəkətli Novruz       False  C. Məmmədquluzadə   40.395400
# 143     Bərəkətli Novruz        True         Radiozavod   40.371819
# ...                  ...         ...                ...         ...
# 438711  Bərəkətli Novruz       False     Həzi Aslanov-2   40.372750
# 438822  Bərəkətli Novruz       False   Xalqlar dostluğu   40.394605
# 438823  Bərəkətli Novruz       False   Xalqlar dostluğu   40.394605
# 438824  Bərəkətli Novruz       False   Xalqlar dostluğu   40.394605
# 438825  Bərəkətli Novruz       False   Xalqlar dostluğu   40.394605
#
#         magaza_long               magaza_location
# 126       49.828833      POINT(49.828833 40.3954)
# 127       49.828833      POINT(49.828833 40.3954)
# 128       49.828833      POINT(49.828833 40.3954)
# 129       49.828833      POINT(49.828833 40.3954)
# 143       49.946795  POINT(49.9467952 40.3718189)
# ...             ...                           ...
# 438711    49.838400       POINT(49.8384 40.37275)
# 438822    49.953685    POINT(49.953685 40.394605)
# 438823    49.953685    POINT(49.953685 40.394605)
# 438824    49.953685    POINT(49.953685 40.394605)
# 438825    49.953685    POINT(49.953685 40.394605)
#
# [36721 rows x 13 columns]

# %%
novruz["mehsul_kateqoriya"].value_counts()
# Out:
# Şirniyyat                   8464
# Məişət məhsulları           2028
#  Yuyucu, təmizləyicilər     1789
# Meyvə Şirələri              1729
# Qab-qacaq                   1378
#                             ...
# Şampan                        18
# Donmuş məhsullar               7
# Dondurulmuş məhsullar          4
# Göyərti                        4
# 1                              4
# Name: mehsul_kateqoriya, Length: 67, dtype: int64

# %%
# qrafiklə göstərmək

a = novruz["mehsul_kateqoriya"].value_counts().values
b = novruz["mehsul_kateqoriya"].value_counts().index


plt.figure(figsize = (11,7))
ax = sns.barplot(x = a[:5], y = b[:5]);
plt.title("Novruz endirimində ən çox satılan top 5 məhsul kateqoriyası", fontsize = 14, fontweight = "bold")
plt.xticks(fontsize = 12, fontweight = "bold", color = "b")
plt.xlabel("Satış sayı", fontsize = 15, fontweight = "bold", color = "b")
plt.yticks(fontsize = 14, fontweight = "bold", color = "r")
for i, v in enumerate(a[:5]):
    ax.text(v + 0.5, i + .05, str(v), color='blue', va = "bottom", fontweight='bold')

plt.savefig("Kateqoriyalar.png", dpi = 80, bbox_inches = "tight")

# %%
# ən çox satılan məhsul kateqoriyasını ayırmaq

sirniyyat = novruz[novruz["mehsul_kateqoriya"] == "Şirniyyat"]

# %%
sirniyyat["magaza_ad"].value_counts()
# Out:
# 28-May               448
# Badamdar             435
# 8 mkr                433
# Həzi Aslanov-2       431
# C. Məmmədquluzadə    419
# Ayna Sultanova       419
# Xırdalan             417
# N.Nərimanov          411
# Yeni Yasamal         411
# Zabrat               409
# Xətai                405
# Nərimanov-2          404
# 20 yanvar            401
# Hipermarket          400
# Əhmədli              388
# Həzi Aslanov-1       384
# Xalqlar dostluğu     384
# M. Əcəmi             383
# Radiozavod           372
# Maşın bazarı         356
# Yasamal              354
# Name: magaza_ad, dtype: int64

# %%
# qrafiklə göstərmək

x = sirniyyat["magaza_ad"].value_counts().values
y = sirniyyat["magaza_ad"].value_counts().index

plt.figure(figsize = (11,8))
plt.title("Şirniyyat məhsullarının filiallar üzrə satışı", fontsize = 15, fontweight = "bold")
plt.xticks(fontsize = 13, fontweight = "bold", color = "b")
plt.xlabel("Satış sayı", fontsize = 15, fontweight = "bold", color = "b")
plt.yticks(fontsize = 13, fontweight = "bold", color = "r")
ax = sns.barplot(x = x, y = y, estimator=sum, palette="viridis");
for i, v in enumerate(x):
    ax.text(v + 3, i + .1, str(v), color='blue', fontweight='bold')

plt.savefig("qrafik.png", dpi = 90, bbox_inches = "tight")
