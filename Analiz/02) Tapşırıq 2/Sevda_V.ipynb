# %% [markdown]
# # Tapşırıq 2.
#
# ## Datasetdə bəzi yerlərdə məhsul adları yoxdur - çatışmayan verilənlər mövcuddur, zəhmət olmasa çatışmayan verilənləri ən optimal alternativlə əvəzləyərək, problemi həll edin.

# %%
import pandas as pd

# %%
df = pd.read_csv("esas_mehsullar.csv")
data = df.copy()
data.head()
# Out:
#    column_a  satish_kodu  mehsul_kodu  \
# 0         0       577571         3334
# 1         1       577571         4674
# 2         2       577571         8388
# 3         3       577571         6017
# 4         4       577571         8297
#
#                                       mehsul_ad  mehsul_kateqoriya  \
# 0  GONDOL SIMPLE LABABO VE BUZLUK HALISI G61*50  Məişət məhsulları
# 1                              TAXTA BICAQ 3232          Qab-qacaq
# 2                        VITA 1LT ANANAS SIRESI     Meyvə Şirələri
# 3          GILAN BAGDAN 1LT SARI GAVALI KOMPOTU          Kompotlar
# 4      OSRAM SUPERSTAR LAMPA 64544A ECO 57W E27  Məişət məhsulları
#
#    mehsul_qiymet        satish_tarixi  endirim_kompaniya  bonus_kart  \
# 0           3.68  2019-07-19T12:29:00  Sərin Yay günləri        True
# 1           2.25  2019-07-19T12:29:00  Sərin Yay günləri        True
# 2           2.50  2019-07-19T12:29:00  Sərin Yay günləri        True
# ...

# %%
# çatışmayan məlumatların cəmi

data.isnull().sum()
# Out:
# column_a                  0
# satish_kodu               0
# mehsul_kodu               0
# mehsul_ad               771
# mehsul_kateqoriya         0
# mehsul_qiymet           771
# satish_tarixi             0
# endirim_kompaniya    220929
# bonus_kart                0
# magaza_ad                 0
# magaza_lat                0
# magaza_long               0
# magaza_location           0
# dtype: int64

# %% [markdown]
# # endirim kompaniya sütunu

# %%
# boş olan sütun və sətirlər

data[data["endirim_kompaniya"].isnull()]
# Out:
#         column_a  satish_kodu  mehsul_kodu  \
# 8              8       583812         6131
# 9              9       583812         3545
# 10            10       583812         2957
# 11            11       469379         8787
# 14            14       469379         8047
# ...          ...          ...          ...
# 438795    438795       995231         9926
# 438796    438796       995231         4188
# 438801    438801       700090         9121
# 438809    438809       951192         3351
# 438818    438818       497589         3215
#
#                                                 mehsul_ad  \
# 8            LUCK SIAM 565GR ANANAS DILIMLERI SIROPDA D/Q
# 9                  SOKOLAD ULDUZ FAVO SOKOLAD,PORTAGAL KG
# 10      MARANDI 750ML YANARDAG QIRMIZI KEMSIRIN SERAB S/Q
# 11                              OLEYNA 1LT GUNEBAXAN YAGI
# 14                        MERRY TEMIZLIK BEZI MOP 40SM*2N
# ...                                                   ...
# ...

# %%
# boş olan dəyərləri "kompaniya yoxdur" sözü ilə əvəzləmək

data["endirim_kompaniya"].fillna("Kompaniya yoxdur", inplace = True)

# %%
data.head(10)
# Out:
#    column_a  satish_kodu  mehsul_kodu  \
# 0         0       577571         3334
# 1         1       577571         4674
# 2         2       577571         8388
# 3         3       577571         6017
# 4         4       577571         8297
# 5         5       577571         4695
# 6         6       577571         6803
# 7         7       577571         7492
# 8         8       583812         6131
# 9         9       583812         3545
#
#                                       mehsul_ad    mehsul_kateqoriya  \
# 0  GONDOL SIMPLE LABABO VE BUZLUK HALISI G61*50    Məişət məhsulları
# 1                              TAXTA BICAQ 3232            Qab-qacaq
# 2                        VITA 1LT ANANAS SIRESI       Meyvə Şirələri
# 3          GILAN BAGDAN 1LT SARI GAVALI KOMPOTU            Kompotlar
# 4      OSRAM SUPERSTAR LAMPA 64544A ECO 57W E27    Məişət məhsulları
# 5                      BEKO 2111P  DEM SAMOVARI    Məişət məhsulları
# ...

# %%
data.isnull().sum()
# Out:
# column_a               0
# satish_kodu            0
# mehsul_kodu            0
# mehsul_ad            771
# mehsul_kateqoriya      0
# mehsul_qiymet        771
# satish_tarixi          0
# endirim_kompaniya      0
# bonus_kart             0
# magaza_ad              0
# magaza_lat             0
# magaza_long            0
# magaza_location        0
# dtype: int64

# %% [markdown]
# # mehsul_ad və mehsul_qiymet sütunu

# %%
# boş olan sütun və sətirlər

data[data[["mehsul_ad","mehsul_qiymet"]].isna().any(axis = 1)]
# Out:
#         column_a  satish_kodu  mehsul_kodu mehsul_ad mehsul_kateqoriya  \
# 794          794       511926         4269       NaN   Enerji içkiləri
# 1108        1108       970854         7799       NaN   Enerji içkiləri
# 1289        1289       915436         3479       NaN          Şərablar
# 1609        1609       680964         4217       NaN   Enerji içkiləri
# 2111        2111       608510         4463       NaN   Enerji içkiləri
# ...          ...          ...          ...       ...               ...
# 436244    436244       902830         7903       NaN   Enerji içkiləri
# 436642    436642       461209         6672       NaN          Şərablar
# 437759    437759       663696         7903       NaN   Enerji içkiləri
# 438021    438021       671973         5650       NaN          Şərablar
# 438695    438695       535626         8087       NaN          Şərablar
#
#         mehsul_qiymet        satish_tarixi  endirim_kompaniya  bonus_kart  \
# ...

# %% [markdown]
# ## Birinci metod

# %%
# boş olan bütün verilənləri datadan silmək

data = data.dropna()

# %%
data.isnull().sum()
# Out:
# column_a             0
# satish_kodu          0
# mehsul_kodu          0
# mehsul_ad            0
# mehsul_kateqoriya    0
# mehsul_qiymet        0
# satish_tarixi        0
# endirim_kompaniya    0
# bonus_kart           0
# magaza_ad            0
# magaza_lat           0
# magaza_long          0
# magaza_location      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438055 entries, 0 to 438825
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   column_a           438055 non-null  int64
#  1   satish_kodu        438055 non-null  int64
#  2   mehsul_kodu        438055 non-null  int64
#  3   mehsul_ad          438055 non-null  object
#  4   mehsul_kateqoriya  438055 non-null  object
#  5   mehsul_qiymet      438055 non-null  float64
#  6   satish_tarixi      438055 non-null  object
#  7   endirim_kompaniya  438055 non-null  object
#  8   bonus_kart         438055 non-null  bool
#  9   magaza_ad          438055 non-null  object
#  10  magaza_lat         438055 non-null  float64
#  11  magaza_long        438055 non-null  float64
#  12  magaza_location    438055 non-null  object
# dtypes: bool(1), float64(3), int64(3), object(6)
# memory usage: 43.9+ MB

# %%
# indexləri sıfırlamaq

data.reset_index(drop=True, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438055 entries, 0 to 438054
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   column_a           438055 non-null  int64
#  1   satish_kodu        438055 non-null  int64
#  2   mehsul_kodu        438055 non-null  int64
#  3   mehsul_ad          438055 non-null  object
#  4   mehsul_kateqoriya  438055 non-null  object
#  5   mehsul_qiymet      438055 non-null  float64
#  6   satish_tarixi      438055 non-null  object
#  7   endirim_kompaniya  438055 non-null  object
#  8   bonus_kart         438055 non-null  bool
#  9   magaza_ad          438055 non-null  object
#  10  magaza_lat         438055 non-null  float64
#  11  magaza_long        438055 non-null  float64
#  12  magaza_location    438055 non-null  object
# dtypes: bool(1), float64(3), int64(3), object(6)
# memory usage: 40.5+ MB

# %%
data.index
# Out:
# RangeIndex(start=0, stop=438055, step=1)

# %% [markdown]
# ## İkinci metod

# %%
data = df.copy()
data.isnull().sum()
# Out:
# column_a                  0
# satish_kodu               0
# mehsul_kodu               0
# mehsul_ad               771
# mehsul_kateqoriya         0
# mehsul_qiymet           771
# satish_tarixi             0
# endirim_kompaniya    220929
# bonus_kart                0
# magaza_ad                 0
# magaza_lat                0
# magaza_long               0
# magaza_location           0
# dtype: int64

# %%
data["endirim_kompaniya"].fillna("Kompaniya yoxdur", inplace=True)

# %%
data.isnull().sum()
# Out:
# column_a               0
# satish_kodu            0
# mehsul_kodu            0
# mehsul_ad            771
# mehsul_kateqoriya      0
# mehsul_qiymet        771
# satish_tarixi          0
# endirim_kompaniya      0
# bonus_kart             0
# magaza_ad              0
# magaza_lat             0
# magaza_long            0
# magaza_location        0
# dtype: int64

# %%
# boş olan sütun və sətirlər

data[data[["mehsul_ad", "mehsul_qiymet"]].isnull().any(axis = 1)]
# Out:
#         column_a  satish_kodu  mehsul_kodu mehsul_ad mehsul_kateqoriya  \
# 794          794       511926         4269       NaN   Enerji içkiləri
# 1108        1108       970854         7799       NaN   Enerji içkiləri
# 1289        1289       915436         3479       NaN          Şərablar
# 1609        1609       680964         4217       NaN   Enerji içkiləri
# 2111        2111       608510         4463       NaN   Enerji içkiləri
# ...          ...          ...          ...       ...               ...
# 436244    436244       902830         7903       NaN   Enerji içkiləri
# 436642    436642       461209         6672       NaN          Şərablar
# 437759    437759       663696         7903       NaN   Enerji içkiləri
# 438021    438021       671973         5650       NaN          Şərablar
# 438695    438695       535626         8087       NaN          Şərablar
#
#         mehsul_qiymet        satish_tarixi  endirim_kompaniya  bonus_kart  \
# ...

# %%
# boş olan məhsul adlarını həmin sətirdəki məhsul kateqoriyası ilə əvəzləmək

data["mehsul_ad"].fillna(data["mehsul_kateqoriya"], inplace=True)

# %%
data.isnull().sum()
# Out:
# column_a               0
# satish_kodu            0
# mehsul_kodu            0
# mehsul_ad              0
# mehsul_kateqoriya      0
# mehsul_qiymet        771
# satish_tarixi          0
# endirim_kompaniya      0
# bonus_kart             0
# magaza_ad              0
# magaza_lat             0
# magaza_long            0
# magaza_location        0
# dtype: int64

# %%
# boş olan məhsul qiymətləri

data[data["mehsul_qiymet"].isnull()].head()
# Out:
#       column_a  satish_kodu  mehsul_kodu        mehsul_ad mehsul_kateqoriya  \
# 794        794       511926         4269  Enerji içkiləri   Enerji içkiləri
# 1108      1108       970854         7799  Enerji içkiləri   Enerji içkiləri
# 1289      1289       915436         3479         Şərablar          Şərablar
# 1609      1609       680964         4217  Enerji içkiləri   Enerji içkiləri
# 2111      2111       608510         4463  Enerji içkiləri   Enerji içkiləri
#
#       mehsul_qiymet        satish_tarixi  endirim_kompaniya  bonus_kart  \
# 794             NaN  2019-09-26T04:33:00   Kompaniya yoxdur        True
# 1108            NaN  2019-06-11T18:05:00   Kompaniya yoxdur       False
# 1289            NaN  2019-08-14T17:41:00   Kompaniya yoxdur        True
# 1609            NaN  2019-07-24T19:04:00  Sərin Yay günləri       False
# 2111            NaN  2019-03-21T03:13:00   Bərəkətli Novruz        True
#
# ...

# %%
# boş olan məhsul qiymətlərini həmin sətirdəki məhsul kateqoriyasının ortalama və ya median dəyərləri ilə doldurmaq

data["mehsul_qiymet"].fillna((data.groupby("mehsul_kateqoriya")["mehsul_qiymet"].transform("median")), inplace = True)

# %%
data.isnull().sum()
# Out:
# column_a             0
# satish_kodu          0
# mehsul_kodu          0
# mehsul_ad            0
# mehsul_kateqoriya    0
# mehsul_qiymet        0
# satish_tarixi        0
# endirim_kompaniya    0
# bonus_kart           0
# magaza_ad            0
# magaza_lat           0
# magaza_long          0
# magaza_location      0
# dtype: int64
